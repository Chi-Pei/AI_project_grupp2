# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('full_dataset_replaced_lat_long.csv')

# %%
dataset.tail()
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 34852  Williamstown  11/81 Melbourne Rd      2    u   450000.0     SP
# 34853  Williamstown    24/18 Station Rd      2    u   475000.0     SP
# 34854  Williamstown     3/2 Thompson St      2    u   520000.0     VB
# 34855       Windsor    4/16 Lewisham Rd      1    u   440000.0     SP
# 34856    Yarraville    12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bathroom  Car  Landsize  \
# 34852          Raine  24/02/2018       6.8    3016.0       NaN  NaN       NaN
# 34853           Greg  24/02/2018       6.8    3016.0       NaN  NaN       NaN
# 34854          Raine  24/02/2018       6.8    3016.0       NaN  NaN       NaN
# 34855         Biggin  24/02/2018       4.6    3181.0       NaN  NaN       NaN
# 34856  hockingstuart  24/02/2018       6.3    3013.0       NaN  NaN       NaN
#
#        BuildingArea  YearBuilt                CouncilArea  Lattitude  \
# ...

# %%
#### 4 is the price
X = dataset.iloc[:,[2,3,8,10,11,12,13,14,16,17]]
y = dataset.iloc[:,4]

# %%
X.head()
# Out:
#    Rooms Type  Distance  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0      2    h       2.5       1.0  1.0     126.0           NaN        NaN
# 1      2    h       2.5       1.0  1.0     202.0           NaN        NaN
# 2      2    h       2.5       1.0  0.0     156.0          79.0     1900.0
# 3      3    u       2.5       2.0  1.0       0.0           NaN        NaN
# 4      3    h       2.5       2.0  0.0     134.0         150.0     1900.0
#
#    Lattitude  Longtitude
# 0   -37.8014    144.9958
# 1   -37.7996    144.9984
# 2   -37.8079    144.9934
# 3   -37.8114    145.0116
# 4   -37.8093    144.9944

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[3])], remainder='passthrough')
dataset = ct.fit_transform(dataset)

# %%
df = pd.DataFrame(dataset)

# %%
#save it to a csv file
columns = ["TypeH", "TypeT", "TypeU", "Suburb","Address","Rooms","Type","Price","Method","SellerG","Date","Distance","Postcode","Bathroom","Car","Landsize","BuildingArea","YearBuilt","CouncilArea","Lattitude","Longtitude","Regionname","Propertycount"]
dataset.iloc[:,[1,2,5,7,10,11,12,13,14,16,17,19,20]]
df.to_csv('full_dataset_OHE.csv'
                          ,index=False,header=True)

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[10])], remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-2685dac0db2f> in <module>
# ----> 1 ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[0][10])], remainder='passthrough')
#
# IndexError: list index out of range

# %%
X = np.array(ct.fit_transform(X))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5bcabb266345> in <module>
# ----> 1 X = np.array(ct.fit_transform(X))
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     504         self._validate_transformers()
#     505         self._validate_column_callables(X)
# --> 506         self._validate_remainder(X)
#     507
#     508         result = self._fit_transform(X, y, _fit_transform_one)
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\compose\_column_transformer.py in _validate_remainder(self, X)
#     322
#     323         # Make it possible to check for reordered named columns on transform
# --> 324         self._has_str_cols = any(_determine_key_type(cols) == 'str'
# ...
